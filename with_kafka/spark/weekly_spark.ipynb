# %%
from pyspark.sql import SparkSession
import os
spark = SparkSession.builder.appName('weekly_spark').getOrCreate()
#spark

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, BooleanType, ArrayType
from pyspark.sql.functions import length, col, count, expr, monotonically_increasing_id, lit

reviews_schema = StructType([
    StructField("App ID", IntegerType(), True),
    StructField("Review", StringType(), True),
    StructField("Voted Up", StringType(), True)
])

weekly_top_news_schema = StructType([
    StructField("appnews", StructType([
        StructField("appid", IntegerType()),
        StructField("newsitems", ArrayType(StructType([
            StructField("gid", StringType()),
            StructField("title", StringType()),
            StructField("url", StringType()),
            StructField("is_external_url", BooleanType()),
            StructField("author", StringType()),
            StructField("contents", StringType()),
            StructField("feedlabel", StringType()),
            StructField("date", IntegerType()),
            StructField("feedname", StringType()),
            StructField("feed_type", IntegerType()),
            StructField("appid", IntegerType()),
            StructField("tags", ArrayType(StringType()))
        ]))),
        StructField("count", IntegerType())
    ]))
])

top_sellers_schema = StructType([
    StructField("Rank", IntegerType(), True),
    StructField("Game Name", StringType(), True),
    StructField("Free to Play", IntegerType(), True),
    ])

top_sellers_appids_schema = StructType([
    StructField("App ID", IntegerType(), True),
])

news_schema = StructType([
    StructField("App ID", IntegerType(), True),
    StructField("News 1", StringType(), True),
    StructField("News 2", StringType(), True),
    StructField("News 3", StringType(), True),
    StructField("News 4", StringType(), True),
    StructField("News 5", StringType(), True),
    StructField("News 6", StringType(), True),
    StructField("News 7", StringType(), True),
    StructField("News 7", StringType(), True),
    StructField("News 8", StringType(), True),
    StructField("News 10", StringType(), True)
])

# %%
WEEKLY_DATA_PATH = r'../data/weekly_data/'
reviews_path = os.path.join(WEEKLY_DATA_PATH, 'reviews/')
FILE_DATE = None

try:
    csv_files = [f for f in os.listdir(reviews_path) if f.endswith('.csv')]
    if csv_files:
        csv_file = csv_files[0]
        FILE_DATE = csv_file[0].split('.')[0].split('_')[0]
        csv_file_path = os.path.join(reviews_path, csv_file)
        most_daily_played = spark.read.csv(csv_file_path, header=True, schema=reviews_schema)
    else:
        print("No CSV files found in the 'reviews_path' directory.")
except Exception as e:
    print("An error occurred while reading the CSV file:", e)

# %%
# Cleaning the data
most_daily_played = most_daily_played.na.drop(subset=["Review", "Voted Up", "App ID"])
most_daily_played = most_daily_played.filter(length(col("Review")) >= 2)

# Counting the number of positive and negative reviews
counted_reviews = most_daily_played.groupBy("App ID").pivot("Voted Up", ["pos", "neg"]).agg(count("*").alias("count"))

# Seprarating the positive and negative reviews
neg_reviews_df = most_daily_played.filter(most_daily_played["Voted Up"] == "neg")
pos_reviews_df = most_daily_played.filter(most_daily_played["Voted Up"] == "pos")

neg_reviews_df = neg_reviews_df.withColumn("FILE_DATE", lit(FILE_DATE))
pos_reviews_df = pos_reviews_df.withColumn("FILE_DATE", lit(FILE_DATE))
counted_reviews = counted_reviews.withColumn("FILE_DATE", lit(FILE_DATE))

# %%
#Top_sellers
WEEKLY_TOP_SELLERS_PATH = WEEKLY_DATA_PATH + r'top_sellers/'
files = os.listdir(WEEKLY_TOP_SELLERS_PATH)

FILE_DATE = None
try:
    csv_file1 = [f for f in files if f.endswith('weekly_top_sellers.csv')]
    FILE_DATE = csv_file1[0].split('.')[0].split('_')[0]
    top_sellers_games = spark.read.csv(
        WEEKLY_TOP_SELLERS_PATH + csv_file1[0],
        header=True,
        schema=top_sellers_schema  
    )
    csv_file2 = [f for f in files if f.endswith('weekly_top_sellers_appIds.csv')]
    FILE_DATE = csv_file2[0].split('.')[0].split('_')[0]
    top_sellers_appids = spark.read.csv(
        WEEKLY_TOP_SELLERS_PATH + csv_file2[0],
        header=True,
        schema=top_sellers_appids_schema  
    )
    top_sellers_appids = top_sellers_appids.withColumn(
    "Rank",(monotonically_increasing_id() + 1).cast("int"))
    top_sellers = top_sellers_games.join(top_sellers_appids, on=["Rank"], how="inner")
    top_sellers = top_sellers.withColumn("FILE_DATE", lit(FILE_DATE))
    #top_sellers.show()   

except Exception as e:
    print("An error occurred while reading the CSV file:", e)

# %%
neg_reviews_path = r"../saved_data/weekly_data/neg_reviews"
pos_reviews_path = r"../saved_data/weekly_data/pos_reviews"
counted_reviews_path = r"../saved_data/weekly_data/counted_reviews"
top_sellers_path = r"../saved_data/weekly_data/top_sellers"

# Save the DataFrame as CSV
neg_reviews_df.write.format("csv").mode("overwrite").option("header", "true").save(neg_reviews_path)
pos_reviews_df.write.format("csv").mode("overwrite").option("header", "true").save(pos_reviews_path)
counted_reviews.write.format("csv").mode("overwrite").option("header", "true").save(counted_reviews_path)
top_sellers.write.format("csv").mode("overwrite").option("header", "true").save(top_sellers_path)

# %%
# need to work on news
import pandas as pd
import json

# %%
WEEKLY_NEWS_PATH = WEEKLY_DATA_PATH + r'news/'
files = os.listdir(WEEKLY_NEWS_PATH)

# Create an empty list to store DataFrames from each JSON file
dfs = []

try:
    for file in files:
        with open(WEEKLY_NEWS_PATH + file, 'r') as json_file:
            json_data = json.load(json_file)

            df = pd.DataFrame()  # Create a new DataFrame for each JSON file

            for i in range(len(json_data['appnews']['newsitems'])):
                column_name = f"contents_{i}" 
                value = json_data['appnews']['newsitems'][i]['contents']
                
                if isinstance(value, (list, dict)):
                    value = str(value)
                df[column_name] = [value]

            df['App ID'] = json_data['appnews']['appid']

            # Append the DataFrame to the list
            dfs.append(df)

except Exception as e:
    print("An error occurred while reading the JSON file:", e)

# Concatenate all DataFrames in the list into a single DataFrame
news_df = pd.concat(dfs, ignore_index=True)

# The 'news_df' DataFrame now contains data from all JSON files
print(news_df)
# Out:
#                                           contents_0  \
# 0  Valve looks to be teasing the imminent release...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  Моддер Halk Hogan PL спустя всего две недели п...
# 3  According to the voice of Astarion himself, th...
# 4  Датамайнер под ником<strong> TheThiny </strong...
# 5  <strong>Payday 3</strong> is finally here, but...
# 6  Heroes of Arkesia, The newest Ark Pass arrives...
# 7  Компания Neowiz Games опубликовал обращение, в...
# 8  n increase in Destiny 2 error code encounters ...
# 9  Take heed, Legends, night has fallen and with ...
#
#                                           contents_1  \
# 0  Office Adjusted the weight of the vending mach...
# 1  <a href="https://steamdb.info/topsellers/2023W...
# 2  <strong>Starfield</strong> can be a rather gor...
# 3  <strong>Larian Studios </strong>сообщила о вып...
# 4  Watch Hollow experience Mortal Kombat 1's stor...
# 5  <strong>Payday 3</strong> has only just releas...
# 6  https://images.ctfassets.net/umhrp0op95v1/S6BJ...
# 7  <strong>Who is in the Lies of P cast?</strong>...
# 8  <strong>Update:</strong> It was fun while it l...
# 9  Could Titanfall 3 finally be on the way? It’s ...
#
#                                           contents_2  \
# 0  Anubis Various clipping adjustments Rebalanced...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  <strong>Starfield </strong>is the biggest Beth...
# 3  If you've finished <strong>Baldur's Gate 3</st...
# 4  RESOLVED The performance issue some PC players...
# 5  <strong>What are the Payday 3 error codes?</st...
# 6  https://images.ctfassets.net/umhrp0op95v1/5Adj...
# 7  Hello citizens of Krat, It's Choi Ji Won, the ...
# 8  Bungie has announced in its latest <strong>Des...
# 9  After years of being unplayable online, <stron...
#
#                                           contents_3  \
# 0  Various bug fixes and tweaks for all shipped m...
# 1  SteamOS 3.5 has just been released to the Prev...
# 2  Seamless travel between planets is one of the ...
# 3  <strong>Baldur's Gate 3 patch notes</strong> a...
# 4  Многочисленные проблемы, наблюдающиеся в Switc...
# 5  <strong>Payday 3</strong> Steam reviews are of...
# 6  The <strong>Lost Ark</strong> September Update...
# 7  Соулслайк-экшен <strong>Lies of P </strong>по ...
# 8  This week in Destiny, we have to talk about Le...
# 9  Often hailed as one of the <a href="https://ww...
#
#                                           contents_4  \
# 0  Mirage Fixed a pixel boost on pillars in B bom...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  <strong>Starfield</strong>&apos;s community ke...
# 3  Larian Studios has released patch 3 for <a hre...
# 4  19 сентября состоялся полноценный релиз <stron...
# 5  <strong>September 23, 2023:</strong> It seems ...
# 6  Heroes of Arkesia, The September “Jump to the ...
# 7  <strong>Is Lies of P Steam Deck compatible? </...
# 8  There must be an almost erotic thrill to elimi...
# 9  The Messengers of Death have arrived, turning ...
#
#                                           contents_5  \
# 0  Ancient Various bug fixes and tweaks Various b...
# 1  We have just shipped an updated Steam Deck Cli...
# 2  Bummed that your <a href="https://www.pcgamer....
# 3  <a href="https://www.pcgamer.com/baldurs-gate-...
# 4  Спустя две недели доминирования <strong>Starfi...
# 5  <strong>What are the best Payday 3 mods?</stro...
# 6  Heroes of Arkesia, We’re excited to announce t...
# 7  Спустя две недели доминирования <strong>Starfi...
# 8  Recently, my Destiny 2 clanmates and I took th...
# 9  {STEAM_CLAN_IMAGE}/38098458/5530ddcd7729f12490...
#
#                                           contents_6  \
# 0  Overpass Various bug fixes and tweaks Added cu...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  <strong>Starfield</strong> Steam reviews give ...
# 3  Hello everyone, Patch 3 is now live for Baldur...
# 4  <a href="https://steamdb.info/topsellers/2023W...
# 5  <strong>Payday 3</strong> is finally here, and...
# 6  <strong>Lost Ark</strong> is an aesthetically ...
# 7  Hello from the Lies of P Team. We have receive...
# 8  This week in Destiny, Crota is back in all his...
# 9  {STEAM_CLAN_IMAGE}/38098458/86ea72d94b9d1aff0f...
#
#                                           contents_7  \
# 0  Ancient Fixed CT spawn area shape in minimap O...
# 1  <a href="https://steamdb.info/topsellers/2023W...
# 2  The <a href="https://www.pcgamer.com/starfield...
# 3  The <strong>Baldur's Gate 3 patch notes</stron...
# 4  В сети появился видеоролик, в котором проводит...
# 5  <a href="https://steamdb.info/app/1272080/char...
# 6  Heroes of Arkesia, Join us for the live finale...
# 7  <strong>Lies of P </strong>has only just relea...
# 8  Completing <strong>Metamorphosis Attunement</s...
# 9  Join EA Play to make your games more rewarding...
#
#                                           contents_8  \
# 0  Inferno Various bug fixes and tweaks Players w...
# 1  We have just shipped an updated Steam Deck Cli...
# 2  Bethesda <a href="https://twitter.com/Starfiel...
# 3  It&apos;s about time&#x2014;<a href="https://w...
# 4  With its steadfast love of imploding skulls an...
# 5  As someone who played and very much enjoyed th...
# 6  https://images.ctfassets.net/umhrp0op95v1/7zcO...
# 7  <a href="https://steamdb.info/topsellers/2023W...
# 8  Pre-order today The Final Shape has been revea...
# 9  It's been a bit of a saga for Apex Legends pla...
#
#                                           contents_9   App ID
# 0  Added Premier mode Added a visible CS Rating a...      730
# 1  Note: This update is for the Steam Deck Beta a...  1675200
# 2  fter all these years, Bethesda Game Studios ha...  1716740
# 3  The next patch for <a href="https://www.pcgame...  1086940
# 4  <strong>Mortal Kombat 1</strong> isn't even te...  1971870
# 5  <strong>What are the best Payday 3 weapons?</s...  1272080
# 6  Heroes of Arkesia, We’re back with your host R...  1599340
# 7  We're coming towards the end of September, so ...  1627720
# 8  It&apos;s been two weeks since the mood music ...  1085660
# 9  Around five days ago I reported on Apex Legend...  1172470

# %%
news_df
# Out:
#                                           contents_0  \
# 0  Valve looks to be teasing the imminent release...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  Моддер Halk Hogan PL спустя всего две недели п...
# 3  According to the voice of Astarion himself, th...
# 4  Датамайнер под ником<strong> TheThiny </strong...
# 5  <strong>Payday 3</strong> is finally here, but...
# 6  Heroes of Arkesia, The newest Ark Pass arrives...
# 7  Компания Neowiz Games опубликовал обращение, в...
# 8  n increase in Destiny 2 error code encounters ...
# 9  Take heed, Legends, night has fallen and with ...
#
#                                           contents_1  \
# 0  Office Adjusted the weight of the vending mach...
# 1  <a href="https://steamdb.info/topsellers/2023W...
# 2  <strong>Starfield</strong> can be a rather gor...
# 3  <strong>Larian Studios </strong>сообщила о вып...
# 4  Watch Hollow experience Mortal Kombat 1's stor...
# 5  <strong>Payday 3</strong> has only just releas...
# 6  https://images.ctfassets.net/umhrp0op95v1/S6BJ...
# 7  <strong>Who is in the Lies of P cast?</strong>...
# 8  <strong>Update:</strong> It was fun while it l...
# 9  Could Titanfall 3 finally be on the way? It’s ...
#
#                                           contents_2  \
# 0  Anubis Various clipping adjustments Rebalanced...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  <strong>Starfield </strong>is the biggest Beth...
# 3  If you've finished <strong>Baldur's Gate 3</st...
# 4  RESOLVED The performance issue some PC players...
# 5  <strong>What are the Payday 3 error codes?</st...
# 6  https://images.ctfassets.net/umhrp0op95v1/5Adj...
# 7  Hello citizens of Krat, It's Choi Ji Won, the ...
# 8  Bungie has announced in its latest <strong>Des...
# 9  After years of being unplayable online, <stron...
#
#                                           contents_3  \
# 0  Various bug fixes and tweaks for all shipped m...
# 1  SteamOS 3.5 has just been released to the Prev...
# 2  Seamless travel between planets is one of the ...
# 3  <strong>Baldur's Gate 3 patch notes</strong> a...
# 4  Многочисленные проблемы, наблюдающиеся в Switc...
# 5  <strong>Payday 3</strong> Steam reviews are of...
# 6  The <strong>Lost Ark</strong> September Update...
# 7  Соулслайк-экшен <strong>Lies of P </strong>по ...
# 8  This week in Destiny, we have to talk about Le...
# 9  Often hailed as one of the <a href="https://ww...
#
#                                           contents_4  \
# 0  Mirage Fixed a pixel boost on pillars in B bom...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  <strong>Starfield</strong>&apos;s community ke...
# 3  Larian Studios has released patch 3 for <a hre...
# 4  19 сентября состоялся полноценный релиз <stron...
# 5  <strong>September 23, 2023:</strong> It seems ...
# 6  Heroes of Arkesia, The September “Jump to the ...
# 7  <strong>Is Lies of P Steam Deck compatible? </...
# 8  There must be an almost erotic thrill to elimi...
# 9  The Messengers of Death have arrived, turning ...
#
#                                           contents_5  \
# 0  Ancient Various bug fixes and tweaks Various b...
# 1  We have just shipped an updated Steam Deck Cli...
# 2  Bummed that your <a href="https://www.pcgamer....
# 3  <a href="https://www.pcgamer.com/baldurs-gate-...
# 4  Спустя две недели доминирования <strong>Starfi...
# 5  <strong>What are the best Payday 3 mods?</stro...
# 6  Heroes of Arkesia, We’re excited to announce t...
# 7  Спустя две недели доминирования <strong>Starfi...
# 8  Recently, my Destiny 2 clanmates and I took th...
# 9  {STEAM_CLAN_IMAGE}/38098458/5530ddcd7729f12490...
#
#                                           contents_6  \
# 0  Overpass Various bug fixes and tweaks Added cu...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  <strong>Starfield</strong> Steam reviews give ...
# 3  Hello everyone, Patch 3 is now live for Baldur...
# 4  <a href="https://steamdb.info/topsellers/2023W...
# 5  <strong>Payday 3</strong> is finally here, and...
# 6  <strong>Lost Ark</strong> is an aesthetically ...
# 7  Hello from the Lies of P Team. We have receive...
# 8  This week in Destiny, Crota is back in all his...
# 9  {STEAM_CLAN_IMAGE}/38098458/86ea72d94b9d1aff0f...
#
#                                           contents_7  \
# 0  Ancient Fixed CT spawn area shape in minimap O...
# 1  <a href="https://steamdb.info/topsellers/2023W...
# 2  The <a href="https://www.pcgamer.com/starfield...
# 3  The <strong>Baldur's Gate 3 patch notes</stron...
# 4  В сети появился видеоролик, в котором проводит...
# 5  <a href="https://steamdb.info/app/1272080/char...
# 6  Heroes of Arkesia, Join us for the live finale...
# 7  <strong>Lies of P </strong>has only just relea...
# 8  Completing <strong>Metamorphosis Attunement</s...
# 9  Join EA Play to make your games more rewarding...
#
#                                           contents_8  \
# 0  Inferno Various bug fixes and tweaks Players w...
# 1  We have just shipped an updated Steam Deck Cli...
# 2  Bethesda <a href="https://twitter.com/Starfiel...
# 3  It&apos;s about time&#x2014;<a href="https://w...
# 4  With its steadfast love of imploding skulls an...
# 5  As someone who played and very much enjoyed th...
# 6  https://images.ctfassets.net/umhrp0op95v1/7zcO...
# 7  <a href="https://steamdb.info/topsellers/2023W...
# 8  Pre-order today The Final Shape has been revea...
# 9  It's been a bit of a saga for Apex Legends pla...
#
#                                           contents_9   App ID
# 0  Added Premier mode Added a visible CS Rating a...      730
# 1  Note: This update is for the Steam Deck Beta a...  1675200
# 2  fter all these years, Bethesda Game Studios ha...  1716740
# 3  The next patch for <a href="https://www.pcgame...  1086940
# 4  <strong>Mortal Kombat 1</strong> isn't even te...  1971870
# 5  <strong>What are the best Payday 3 weapons?</s...  1272080
# 6  Heroes of Arkesia, We’re back with your host R...  1599340
# 7  We're coming towards the end of September, so ...  1627720
# 8  It&apos;s been two weeks since the mood music ...  1085660
# 9  Around five days ago I reported on Apex Legend...  1172470

# %%
# Define a function to remove "<strong>" from each cell
def remove_strong(cell):
    if "<strong>" in cell:
        return cell.replace("<strong>", "")
    if "</strong>" in cell:
        return cell.replace("</strong>", "")
    if cell.startswith("<a href="):
        cell = ""
    else:
        return cell

# Apply the function to each cell in the DataFrame (except "App ID" column)
news_df.iloc[:, :-1] = news_df.iloc[:, :-1].applymap(remove_strong)

# %%
news_df
# Out:
#                                           contents_0  \
# 0  Valve looks to be teasing the imminent release...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  Моддер Halk Hogan PL спустя всего две недели п...
# 3  According to the voice of Astarion himself, th...
# 4  Датамайнер под ником TheThiny </strong>раскрыл...
# 5  Payday 3</strong> is finally here, but the Sta...
# 6  Heroes of Arkesia, The newest Ark Pass arrives...
# 7  Компания Neowiz Games опубликовал обращение, в...
# 8  n increase in Destiny 2 error code encounters ...
# 9  Take heed, Legends, night has fallen and with ...
#
#                                           contents_1  \
# 0  Office Adjusted the weight of the vending mach...
# 1                                               None
# 2  Starfield</strong> can be a rather gorgeous ga...
# 3  Larian Studios </strong>сообщила о выпуске тре...
# 4  Watch Hollow experience Mortal Kombat 1's stor...
# 5  Payday 3</strong> has only just released from ...
# 6  https://images.ctfassets.net/umhrp0op95v1/S6BJ...
# 7  Who is in the Lies of P cast?</strong> The cas...
# 8  Update:</strong> It was fun while it lasted, b...
# 9  Could Titanfall 3 finally be on the way? It’s ...
#
#                                           contents_2  \
# 0  Anubis Various clipping adjustments Rebalanced...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  Starfield </strong>is the biggest Bethesda gam...
# 3  If you've finished Baldur's Gate 3</strong> an...
# 4  RESOLVED The performance issue some PC players...
# 5  What are the Payday 3 error codes?</strong> No...
# 6  https://images.ctfassets.net/umhrp0op95v1/5Adj...
# 7  Hello citizens of Krat, It's Choi Ji Won, the ...
# 8  Bungie has announced in its latest Destiny 2</...
# 9  After years of being unplayable online, Titanf...
#
#                                           contents_3  \
# 0  Various bug fixes and tweaks for all shipped m...
# 1  SteamOS 3.5 has just been released to the Prev...
# 2  Seamless travel between planets is one of the ...
# 3  Baldur's Gate 3 patch notes</strong> are here ...
# 4  Многочисленные проблемы, наблюдающиеся в Switc...
# 5  Payday 3</strong> Steam reviews are officially...
# 6  The Lost Ark</strong> September Update is here...
# 7  Соулслайк-экшен Lies of P </strong>по мотивам ...
# 8  This week in Destiny, we have to talk about Le...
# 9  Often hailed as one of the <a href="https://ww...
#
#                                           contents_4  \
# 0  Mirage Fixed a pixel boost on pillars in B bom...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  Starfield</strong>&apos;s community keeps gett...
# 3  Larian Studios has released patch 3 for <a hre...
# 4  19 сентября состоялся полноценный релиз Mortal...
# 5  September 23, 2023:</strong> It seems players ...
# 6  Heroes of Arkesia, The September “Jump to the ...
# 7  Is Lies of P Steam Deck compatible? </strong> ...
# 8  There must be an almost erotic thrill to elimi...
# 9  The Messengers of Death have arrived, turning ...
#
#                                           contents_5  \
# 0  Ancient Various bug fixes and tweaks Various b...
# 1  We have just shipped an updated Steam Deck Cli...
# 2  Bummed that your <a href="https://www.pcgamer....
# 3  <a href="https://www.pcgamer.com/baldurs-gate-...
# 4  Спустя две недели доминирования Starfield</str...
# 5  What are the best Payday 3 mods?</strong> We'r...
# 6  Heroes of Arkesia, We’re excited to announce t...
# 7  Спустя две недели доминирования Starfield</str...
# 8  Recently, my Destiny 2 clanmates and I took th...
# 9  {STEAM_CLAN_IMAGE}/38098458/5530ddcd7729f12490...
#
#                                           contents_6  \
# 0  Overpass Various bug fixes and tweaks Added cu...
# 1  Note: This update is for the Steam Deck Beta a...
# 2  Starfield</strong> Steam reviews give a lower ...
# 3  Hello everyone, Patch 3 is now live for Baldur...
# 4                                               None
# 5  Payday 3</strong> is finally here, and that me...
# 6  Lost Ark</strong> is an aesthetically pleasing...
# 7  Hello from the Lies of P Team. We have receive...
# 8  This week in Destiny, Crota is back in all his...
# 9  {STEAM_CLAN_IMAGE}/38098458/86ea72d94b9d1aff0f...
#
#                                           contents_7  \
# 0  Ancient Fixed CT spawn area shape in minimap O...
# 1                                               None
# 2  The <a href="https://www.pcgamer.com/starfield...
# 3  The Baldur's Gate 3 patch notes</strong> for B...
# 4  В сети появился видеоролик, в котором проводит...
# 5                                               None
# 6  Heroes of Arkesia, Join us for the live finale...
# 7  Lies of P </strong>has only just released, and...
# 8  Completing Metamorphosis Attunement</strong> i...
# 9  Join EA Play to make your games more rewarding...
#
#                                           contents_8  \
# 0  Inferno Various bug fixes and tweaks Players w...
# 1  We have just shipped an updated Steam Deck Cli...
# 2  Bethesda <a href="https://twitter.com/Starfiel...
# 3  It&apos;s about time&#x2014;<a href="https://w...
# 4  With its steadfast love of imploding skulls an...
# 5  As someone who played and very much enjoyed th...
# 6  https://images.ctfassets.net/umhrp0op95v1/7zcO...
# 7                                               None
# 8  Pre-order today The Final Shape has been revea...
# 9  It's been a bit of a saga for Apex Legends pla...
#
#                                           contents_9   App ID
# 0  Added Premier mode Added a visible CS Rating a...      730
# 1  Note: This update is for the Steam Deck Beta a...  1675200
# 2  fter all these years, Bethesda Game Studios ha...  1716740
# 3  The next patch for <a href="https://www.pcgame...  1086940
# 4  Mortal Kombat 1</strong> isn't even technicall...  1971870
# 5  What are the best Payday 3 weapons?</strong> P...  1272080
# 6  Heroes of Arkesia, We’re back with your host R...  1599340
# 7  We're coming towards the end of September, so ...  1627720
# 8  It&apos;s been two weeks since the mood music ...  1085660
# 9  Around five days ago I reported on Apex Legend...  1172470
